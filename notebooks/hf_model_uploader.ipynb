# %%
from service.hf_uploader import HuggingFaceUploader
uploader = HuggingFaceUploader(username="OvidiuT")

# %%
# T5 model
uploader.upload_folder(
    model_name="t5_decorator_model",
    local_folder="./t5_decorator_model_best",
    commit_message="Upload T5 decorator mode model"
)
# Out:
# ✅ Created repo: OvidiuT/t5_decorator_model
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# 📤 Uploaded folder './t5_decorator_model_best' to 'OvidiuT/t5_decorator_model'

# %%
from service.util.path_util import PROJECT_ROOT

uploader.upload_folder(
    model_name="checkpoint-200",
    local_folder= PROJECT_ROOT / "dumitrescustefan_token_output/checkpoint-200-small",
    commit_message="Upload DumitrescuStefan checkpoint 200 small"
)
# Out:
# ✅ Created repo: OvidiuT/checkpoint-200-small
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# 📤 Uploaded folder 'D:\DEV\scraper-news\dumitrescustefan_token_output\checkpoint-200-small' to 'OvidiuT/checkpoint-200-small'

# %%
uploader.upload_file(
    model_name="bert-model-pt",
    file_path= PROJECT_ROOT / "bert_model.pt",
    path_in_repo="bert_model.pt",
    commit_message="Upload TorchScript BERT model"
)
# Out:
# ✅ Created repo: OvidiuT/bert-model-pt
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# 📤 Uploaded file 'D:\DEV\scraper-news\bert_model.pt' to 'OvidiuT/bert-model-pt/bert_model.pt'
